# %% [markdown]
# # Markdown Cell
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/slxuphys/tamu_phys_150/blob/master/lecture/lecture%2002%20markdown.ipynb)

# %% [markdown]
# ## titles
#
# # Physics
# ## classical mechanics
# ### Newton second law
#
# ## font
# physics __physics__
#
# _physics_ ___physics___ ~~physics~~
#
# ## ordered list
# 1. Dirac
# 2. Heisenberg
# 3. Schrodinger
#
# ## unordered list
# - Dirac
# - Heisenberg
# - Schrodinger
# ---
# ### To do list
# - [x] lecture 3
# - [ ] completed

# %% [markdown]
# ## Picture
# ![image.png](attachment:image.png)

# %% [markdown]
# ![imag](https://www.clarkson.edu/sites/default/files/2023-06/Physics-Hero-1600x900.jpg)

# %% [markdown]
# ## Latex equation
# $\pi \alpha \beta \gamma \sigma \chi \xi \lambda \Sigma$
#
# $\pi r^2$
#
# $L_{2+3}$
#
# $\sqrt[3]{a+b}$
#
# $a^{1/n}$
#
# $\frac{a+b}{c+d}$
#
# $e^{i\pi}+1=0$
#
# $\hbar$
#
# ### Display equations
# The Newton's second law is given by
# $$F=ma$$
#
# \begin{equation}
# F=ma
# \end{equation}
# ### Display equation with more lines
# \begin{equation}
# \begin{aligned}
# a=r \sin \theta \\
# b=r \cos \theta
# \end{aligned}
# \end{equation}

# %% [markdown]
# ### Table
# |name|major|hobby|
# |----|-----|-----|
# |Shenglong|Physics|video game|
# |a|b|c|

# %% [markdown]
# ### Link
# www.wiki.com
# ### Clickable Link
# [wiki](www.wiki.com)
