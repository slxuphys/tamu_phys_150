# %% [markdown]
# # TAMU PHYS 150 Lecture 01: Introduction to Programming
# [![Open In Colab](../gallery/colab-badge.svg)](https://colab.research.google.com/github/slxuphys/tamu_phys_150/blob/master/2026/lecture-01-introduction.ipynb)

# %% [markdown]
# # Course Logistics

# %% [markdown]
# ## Instructor
#
# Shenglong Xu
#
# Assistant Professor, Department of Physics & Astronomy
#
# Office: MPHY 404
#
# Email: slxu@tamu.edu
#
# - B.S in Physics, Nanjing University  2007-2011
# - Ohio State University 2011-2013
# - PhD in physics, University of California, San Diego 2013 - 2017
# - Post-Doc, University of Maryland, 2017-2020
# - Texas A&M, 2020 -
#
# Research Areas: Quantum Information, Quantum Computing, Quantum Simulation, Quantum Many-body Physics, Condensed Matter Physics

# %% [markdown]
# ## Teaching Assistant
#
# Zhuowei Zhang
#
# Graduate Student, Department of Physics & Astronomy
#
# Office: MPHY 480
#
# Email: zw.zhang@tamu.edu

# %% [markdown]
# ## Canvas
#
# [Canvas](https://canvas.tamu.edu/) will be used for course syllabus, announcements, assignment submissions, and grade tracking. Students are expected to check Canvas regularly for updates and information related to the course.
#
# !important: check your Canvas notifications settings to ensure you receive announcements immediately. You can adjust your notification preferences in Canvas by clicking on your profile picture, selecting "Notifications," and customizing your settings for course announcements.
#
# Please read the syllabus on Canvas carefully, as it contains important information about the course structure, grading policy, and expectations.

# %% [markdown]
# ## Office Hours
#
# Please fill out the [when to meet](https://www.when2meet.com/?38036526-HjBnY) form to indicate your availability for office hours. The instructor and TA will schedule office hours based on the availability of students. It is __important__ to fill __ALL__ the time slots you are available, as this will help us find a time that works for everyone.

# %% [markdown]
# ## Course Materials
#
# No text book is required for this course. All course materials, including pdf lecture notes (including this one), assignments, and additional resources, will be provided on Canvas.
#
# The lecture notes and interactive Jupyter notebooks (see below) are also hosted on GitHub at [course materials](https://github.com/slxuphys/tamu_phys_150), and they will be updated regularly.
#
# This is a programming & physics course. You are required to bring your laptop to class to code. I highly recommend you to take notes on your laptop as well

# %% [markdown]
# # What's Programming
#
# “Computer programming is the process of designing and building an executable computer program to accomplish a specific computing results…The purpose of programming is to find a sequence of instructions that will __automate__ the performance of a task” – From Wikipedia

# %%
print('hello world')
# Out:
# hello world

# %%
print('hello world')
for i in range(10):
    print('hello world', i)
# Out:
# hello world 0
# hello world 1
# hello world 2
# hello world 3
# hello world 4
# hello world 5
# hello world 6
# hello world 7
# hello world 8
# hello world 9

# %% [markdown]
# ## Programming Languages
#
# Programming languages are the languages we use to communicate with computers. They are used to write programs that tell the computer what to do. There are many programming languages, each with its own syntax and semantics. Some popular programming languages include Python, C++, Java, and JavaScript.
#
# ![common programming languages](../gallery/language.png){width=400px caption="Common programming languages"}

# %% [markdown]
# # What is Jupyter Notebook
# From now on we will use jupyter notebook to write our notes, codes, homework and exams.
#
#
# Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations, and narrative text. It is widely used in data science, scientific computing, and machine learning for its interactive and user-friendly interface.
#
# Any file with the extension `.ipynb` is a Jupyter Notebook file, such as this one.
#
# ## Why Jupyter Notebook
# - Interactive: You can run code in small chunks (cells) and see the results immediately,
#     making it easier to experiment and debug.
# - Versatile: Supports multiple programming languages, including Python, R, and Julia.
# - Rich Media: You can include images, videos, and interactive visualizations in your notebooks.
# - Documentation: You can combine code with narrative text, making it easier to explain your work.
# - Collaboration: Notebooks can be easily shared and collaborated on with others.
# ## How to use Jupyter Notebook
# There are several ways to open and edit Jupyter Notebooks:
# 1. Github: You can view Jupyter Notebooks directly on GitHub, _but you cannot edit them there_.
# 2. Cloud Services: You can open and edit Jupyter Notebooks directly in your web browser using Google Colab or other cloud services.To open this notebook. Go to [Google Colab](https://colab.research.google.com/) and Click on "File" > "Open notebook".
#     - you can open notebooks from your google drive. The notebooks are saved in the Colab Notebooks folder in your google drive.
#     - you can also create a new notebook by clicking "File" > "New notebook".
#     - you edits will be automatically saved in your google drive.
#     - you can also download the notebook to your local computer by clicking "File" > "Download" > "Download .ipynb".
# 3. Local Installation. You need install [anaconda](https://www.anaconda.com/download/success) first, which installs python and jupyter notebook together. Then you can open jupyter notebook from anaconda navigator.  **You need to first open the Jupyter Notebook server from Anaconda Navigator and open any notebook from there. Double click does not work**. This will open a new tab in your web browser, where you can create a new notebook or open an existing one, pretty much like google colab but not requiring Internet.
# 4. [VSCode](https://code.visualstudio.com/): After you install anaconda and VSCode. You can also open and edit Jupyter Notebooks in VSCode. When you open a `.ipynb` file in VSCode, it will automatically open in the notebook editor. When you open a notebook in VSCode for the first time, it will prompt you to install the Jupyter extension if you don't have it installed already. If set up properly, you can now open a notebook in VSCode by double clicking on the file in the file explorer.
#
# Once you have a notebook open no matter which method you use, the interface is pretty much the same. You will see a toolbar at the top, a menu bar below it, and a series of cells below that. Each cell can contain either code or markdown (text). You can run a cell by clicking on the play button on the left side of the cell or by pressing `Shift + Enter`. When you run a code cell, the code will be executed and the output will be displayed below the cell. When you run a markdown cell, the markdown will be rendered as formatted text.
#
# I recommend you try each of the above methods and see which one you like the most.

# %% [markdown]
# Very important: Organize your files and folders properly. You should create a folder for this course, name all the files properly, put all the lecture notes, assignments, and other materials in that folder. Do not put the files in the Downloads folder or on the desktop, as it will be hard to find them later. Google colab automatically name a new notebook as "Untitled.ipynb", please rename it to something meaningful, such as "lecture_01.ipynb" or "assignment_01.ipynb". I do not want to see a file named "Untitled200.ipynb" or "homework copied 100" in your submission.
